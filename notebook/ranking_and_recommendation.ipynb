# %%
import pandas as pd

# Load similarity-scored news
df = pd.read_csv("similarity_scored_news.csv")

# Get top-N recommendations
top_n = 10
recommendations = df.sort_values(by='similarity', ascending=False).head(top_n)

# Save the top recommendations
recommendations.to_csv("sample_recommendations.csv", index=False)

# Display recommendations
recommendations[['title', 'similarity']]
# Out:
#                                                    title  similarity
# 10122  Scientists and researchers reveal 13 dark tech...    0.353518
# 49190  Microsoft AI helps diagnose cervical cancer fa...    0.286566
# 19523  Register for Wednesday's Aging & Innovation Su...    0.261424
# 17049  Foxconn gets permit to remodel Racine building...    0.251224
# 47584  Intel unveils its first chips built for AI in ...    0.242678
# 5010   America's cheapest cities where everyone wants...    0.237026
# 36804  Ask These 7 Genius Questions to Spark Innovati...    0.234925
# 3743   Technology could end drunk driving, and the US...    0.218549
# 40343  Ai Suzuki has 3-stroke lead over Gaby Lopez in...    0.217205
# 23337      Google debuts new Pixel 4 smartphone and more    0.192395
